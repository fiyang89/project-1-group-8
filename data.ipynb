# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Read CSV
file_path = "Resources/population-and-demography.csv"
pop_df = pd.read_csv(file_path)

pop_df
# Out:
#       Country name  Year  Population  \
# 0      Afghanistan  1950     7480464
# 1      Afghanistan  1951     7571542
# 2      Afghanistan  1952     7667534
# 3      Afghanistan  1953     7764549
# 4      Afghanistan  1954     7864289
# ...            ...   ...         ...
# 18283     Zimbabwe  2017    14751101
# 18284     Zimbabwe  2018    15052191
# 18285     Zimbabwe  2019    15354606
# 18286     Zimbabwe  2020    15669663
# 18287     Zimbabwe  2021    15993525
#
#        Population of children under the age of 1  \
# 0                                       301735.0
# 1                                       299368.0
# 2                                       305393.0
# 3                                       311574.0
# 4                                       317584.0
# ...                                          ...
# 18283                                   464521.0
# 18284                                   466524.0
# 18285                                   468844.0
# ...

# %%
# Reduce to first three columns
reduced_df = pop_df[["Country name","Year","Population"]]
reduced_df
# Out:
#       Country name  Year  Population
# 0      Afghanistan  1950     7480464
# 1      Afghanistan  1951     7571542
# 2      Afghanistan  1952     7667534
# 3      Afghanistan  1953     7764549
# 4      Afghanistan  1954     7864289
# ...            ...   ...         ...
# 18283     Zimbabwe  2017    14751101
# 18284     Zimbabwe  2018    15052191
# 18285     Zimbabwe  2019    15354606
# 18286     Zimbabwe  2020    15669663
# 18287     Zimbabwe  2021    15993525
#
# [18288 rows x 3 columns]

# %%
# Restrict to 11 countries: Australia, Brazil, China, Germany, India, Israel, Japan, Russia, South Africa, United Kingdom, United States
# Years: 2010-2018
# Using .loc and .isin
countries = [
    "Australia",
    "Brazil",
    "China",
    "Germany",
    "India",
    "Israel",
    "Japan",
    "Russia",
    "South Africa",
    "United Kingdom",
    "United States"
]

df = reduced_df.loc[(reduced_df["Country name"].isin(countries)) &
                    (reduced_df["Year"] > 2009) &
                    (reduced_df["Year"] < 2019)]
df
# Out:
#         Country name  Year  Population
# 996        Australia  2010    22019166
# 997        Australia  2011    22357032
# 998        Australia  2012    22729272
# 999        Australia  2013    23111788
# 1000       Australia  2014    23469578
# ...              ...   ...         ...
# 17344  United States  2014   322033950
# 17345  United States  2015   324607780
# 17346  United States  2016   327210200
# 17347  United States  2017   329791230
# 17348  United States  2018   332140030
#
# [99 rows x 3 columns]

# %%
# line graph: x-axis: years 2010-2018, y-axis: population, separate color line for each country

for country in countries:
    country_df = df[df["Country name"] == country]
    plt.plot(country_df["Year"], country_df["Population"], label=country)


# Place a legend on the chart in what matplotlib believes to be the "best" location
plt.legend(loc="best")

# Labels
plt.title("Population of 11 Countries, 2010-2018")
plt.xlabel("Years")
plt.ylabel("Population")

# Print our chart to the screen
plt.show()
