# %%
# %matplotlib notebook

# %%
#Import Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import linregress

# %%
#Csv Source - Read in File - https://ourworldindata.org/life-expectancy
df_life_expectancy = pd.read_csv("life-expectancy.csv")

# %%
#Create Data Frame
df_life_expectancy
# Out:
#             Entity Code  Year  Life expectancy at birth (historical)
# 0      Afghanistan  AFG  1950                                   27.7
# 1      Afghanistan  AFG  1951                                   28.0
# 2      Afghanistan  AFG  1952                                   28.4
# 3      Afghanistan  AFG  1953                                   28.9
# 4      Afghanistan  AFG  1954                                   29.2
# ...            ...  ...   ...                                    ...
# 20440     Zimbabwe  ZWE  2017                                   60.7
# 20441     Zimbabwe  ZWE  2018                                   61.4
# 20442     Zimbabwe  ZWE  2019                                   61.3
# 20443     Zimbabwe  ZWE  2020                                   61.1
# 20444     Zimbabwe  ZWE  2021                                   59.3
#
# [20445 rows x 4 columns]

# %%
#Rename Columns
df_life_expectancy = df_life_expectancy.rename(
    columns = {
    "Entity" : "Country name",
    "Life expectancy at birth (historical)" : "Life Expectancy at Birth"
}
)
df_life_expectancy
# Out:
#       Country name Code  Year  Life Expectancy at Birth
# 0      Afghanistan  AFG  1950                      27.7
# 1      Afghanistan  AFG  1951                      28.0
# 2      Afghanistan  AFG  1952                      28.4
# 3      Afghanistan  AFG  1953                      28.9
# 4      Afghanistan  AFG  1954                      29.2
# ...            ...  ...   ...                       ...
# 20440     Zimbabwe  ZWE  2017                      60.7
# 20441     Zimbabwe  ZWE  2018                      61.4
# 20442     Zimbabwe  ZWE  2019                      61.3
# 20443     Zimbabwe  ZWE  2020                      61.1
# 20444     Zimbabwe  ZWE  2021                      59.3
#
# [20445 rows x 4 columns]

# %%
#Set Countries needed and years needed
countries =[" United States", "United Kingdom", "China", "India", "South Africa", "Australia", "Brazil", "Japan", "Russia", "Israel", "Germany"]                         
df = df_life_expectancy.loc[(df_life_expectancy["Country name"].isin(countries)) &
                    (df_life_expectancy["Year"] > 2009) &
                    (df_life_expectancy["Year"] < 2019)]
df
# Out:
#          Country name Code  Year  Life Expectancy at Birth
# 1128        Australia  AUS  2010                      82.1
# 1129        Australia  AUS  2011                      82.1
# 1130        Australia  AUS  2012                      82.3
# 1131        Australia  AUS  2013                      82.6
# 1132        Australia  AUS  2014                      82.6
# ...               ...  ...   ...                       ...
# 19290  United Kingdom  GBR  2014                      81.2
# 19291  United Kingdom  GBR  2015                      80.9
# 19292  United Kingdom  GBR  2016                      81.1
# 19293  United Kingdom  GBR  2017                      81.2
# 19294  United Kingdom  GBR  2018                      81.1
#
# [90 rows x 4 columns]

# %%
#Create Scatter Plot
plt.scatter(df["Country name"], df["Life Expectancy at Birth"])

#Set Title and Labels 
plt.title("Life Expectancy at Birth 2010-2018")
plt.ylabel("Life Expectancy at Birth")
plt.xlabel("Country")
plt.xticks(rotation=15)
plt.grid(True)

#Save Scatter Plot Locally
plt.savefig("Project Images/LifeExpectancyatBirth.png")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df["Life Expectancy at Birth"].mean()
# Out:
# 76.44222222222217

# %%
df.describe()
# Out:
#               Year  Life Expectancy at Birth
# count    90.000000                 90.000000
# mean   2014.000000                 76.442222
# std       2.596454                  6.628827
# min    2010.000000                 58.900000
# 25%    2012.000000                 71.725000
# 50%    2014.000000                 78.900000
# 75%    2016.000000                 82.100000
# max    2018.000000                 84.300000

# %%
df["Life Expectancy at Birth"].min()
# Out:
# 58.9

# %%
df["Life Expectancy at Birth"].max()
# Out:
# 84.3
